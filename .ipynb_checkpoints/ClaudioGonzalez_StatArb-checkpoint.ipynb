# %% [markdown]
# # LATAM Currencies vs Commodities Project Code

# %%
import pandas as pd
from pykalman import KalmanFilter
import numpy as np
import datetime
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
from statsmodels.tsa.stattools import coint
from sklearn.utils import resample
import seaborn as sns; sns.set()
from pandas import Series
from statsmodels.tsa.stattools import adfuller
from scipy import stats
from scipy.odr import Model, Data, ODR
import statsmodels.api as sm
from math import sqrt
pd.options.mode.chained_assignment = None
from scipy.stats import norm

# %% [markdown]
# Import Currency and Commodities Futures Data

# %%
read_excel_commodi = pd.ExcelFile('commodities_latam.xlsx')
x = read_excel_commodi.sheet_names
read_excel_currenc = pd.ExcelFile('latam_currencies.xlsx')
y = read_excel_currenc.sheet_names
exports_latam = pd.read_csv('gdp_latam.csv',index_col = 0)

commodities = []
currencies = []
for i in range(0,len(x)):
    commodities.append(pd.read_excel(read_excel_commodi, x[i], index_col=0))

for i in range(0,len(y)):
    currencies.append(pd.read_excel(read_excel_currenc, y[i],index_col=0))
df_commodities = pd.concat(commodities,axis=1, join='inner').dropna()
df_currencies = pd.concat(currencies,axis=1, join='inner').dropna()
df_total = pd.concat([df_commodities,df_currencies],axis=1, join='inner').dropna()

final_commodities = df_total.iloc[:,0:12]
final_currencies = df_total.iloc[:,12:18]
final_commodities.head()
# Out:
#             Copper/usd  Alum/usd  meat/usd  soybean/usd  crudeoil/usd  \
# Dates
# 2013-10-21      330.35    1817.5   130.125      1303.25         99.22
# 2013-10-22      333.55    1846.5   131.100      1302.25         97.80
# 2013-10-23      326.75    1811.5   131.800      1310.00         96.86
# 2013-10-24      326.35    1827.5   132.800      1309.75         97.11
# 2013-10-25      326.90    1848.0   132.575      1300.00         97.85
#
#             ironore/usd  corn/usd  sugar/usd  coffee/usd  wheat/usd  gold/usd  \
# Dates
# 2013-10-21        980.0    444.00      511.9      137.40     699.75    1315.7
# 2013-10-22        967.0    438.25      513.8      136.20     700.75    1342.5
# 2013-10-23        956.0    442.75      509.0      135.00     701.75    1333.9
# 2013-10-24        938.0    440.25      502.3      134.85     696.50    1350.2
# 2013-10-25        935.0    440.00      503.3      134.25     690.75    1352.4
#
#             silver/usd
# Dates
# 2013-10-21      22.278
# ...

# %%
# Currencies are 1/value of the future meanning 1 BRL = 0.4601 USD
final_currencies.head()
# Out:
#             BRL/USD  CLP/USD  ARS/USD  MXN/USD   COP/USD   PEN/USD
# Dates
# 2013-10-21   0.4601  0.19924   0.1709  0.07698  0.053070  0.361206
# 2013-10-22   0.4603  0.20047   0.1709  0.07787  0.053182  0.362911
# 2013-10-23   0.4587  0.19800   0.1706  0.07696  0.053110  0.362648
# 2013-10-24   0.4515  0.19847   0.1704  0.07711  0.053164  0.361141
# 2013-10-25   0.4571  0.19800   0.1700  0.07763  0.053121  0.362385

# %% [markdown]
# Plot Example of correlated movement between CLP and Copper

# %%
final_commodities_train = df_total.iloc[:725,0:12]
final_currencies_train = df_total.iloc[:725,12:18]
final_commodities_test = df_total.iloc[725:,0:12]
final_currencies_test = df_total.iloc[725:,12:18]


final_commodities_train['Copper/usd'].plot()
final_currencies_train['CLP/USD'].plot(secondary_y=True)
plt.legend(['Copper'])
plt.title('CLP vs Copper')
# Out:
# Text(0.5, 1.0, 'CLP vs Copper')

# %% [markdown]
# Correlation and Cointegration, with an example of the correlation heatmap

# %%
df_corr = pd.concat([final_currencies_train,final_commodities_train], axis=1).corr().filter(final_commodities_train.columns).filter(final_currencies_train.columns, axis=0)

corr_rows = df_corr.index.tolist()
corr_cols = df_corr.columns.tolist()

def cointegration(Y,X):
    X = sm.add_constant(X)
    ols = sm.OLS(Y,X).fit()
    residual = ols.resid
    df_residuals = pd.DataFrame(residual)
    betas = ols.params[1]
    alphas = ols.params[0]
    test_coint = adfuller(residual,autolag='BIC')[0]
    if adfuller(residual,autolag='BIC')[0]<=adfuller(residual,autolag='BIC')[4]['10%']:
        stationarity = 1
    else:
        stationarity = 0
    
    spread = residual#Y - betas*X
    x_t = spread[:-1] - spread.mean()
    x_lag = spread[1:] - spread.mean()
    half = sm.OLS(np.array(x_lag),np.array(x_t)).fit()
    halflife = (np.log(0.5)/np.log(half.params[0]))
        
    return test_coint,halflife,df_residuals,stationarity,betas,alphas

def visualize_data(x,lim):
    #df_corr = pd.concat([final_currencies,final_commodities], axis=1).corr().filter(final_commodities.columns).filter(final_currencies.columns, axis=0)
    print(x.head())
    #takes only data (numbers) inside the corr matrix
    data =  x.values
    fig = plt.figure()
    #1 by 1 in plot number one
    ax = fig.add_subplot(1,1,1)
    ax.set_xticks(np.arange(data.shape[1])+0.5,minor = False)
    ax.set_yticks(np.arange(data.shape[0])+0.5)
    #customizing the plot showing the correlation in color
    #if theres negative correlation if stock goes up other goes down
    heatmap = ax.pcolor(data,cmap = plt.cm.RdYlGn)
    fig.colorbar(heatmap)
    #errases any gaps from the graph
    ax.invert_yaxis()
    #moves ticks from xaxis to the top
    ax.xaxis.tick_top()
    column_labels = x.columns
    row_labels = x.index
    ax.set_xticklabels(column_labels)
    ax.set_yticklabels(row_labels)
    plt.xticks(rotation=90)
    #limit of the color limit of the heatmap of correlationmatrix
    heatmap.set_clim(lim)
    plt.tight_layout()
    plt.show()
    
visualize_data(df_corr,[-0.5,1])
# Out:
#          Copper/usd  Alum/usd  meat/usd  soybean/usd  crudeoil/usd  \
# BRL/USD    0.905552  0.745344  0.442350     0.810261      0.946065
# CLP/USD    0.928844  0.631381  0.395371     0.818696      0.924049
# ARS/USD    0.800036  0.442211  0.623034     0.550516      0.737065
# MXN/USD    0.845839  0.576535  0.696048     0.651637      0.860247
# COP/USD    0.930568  0.713333  0.531590     0.778464      0.961324
#
#          ironore/usd  corn/usd  sugar/usd  coffee/usd  wheat/usd  gold/usd  \
# BRL/USD     0.785944  0.559463   0.069521    0.598385   0.731331  0.547548
# CLP/USD     0.860805  0.616096   0.021154    0.358442   0.771691  0.497864
# ARS/USD     0.628269  0.571840  -0.447120    0.189500   0.835954  0.075327
# MXN/USD     0.608385  0.592718  -0.355886    0.438602   0.842246  0.263075
# COP/USD     0.768279  0.570833  -0.073011    0.522749   0.772015  0.450113
#
#          silver/usd
# BRL/USD    0.758725
# CLP/USD    0.758502
# ARS/USD    0.391343
# MXN/USD    0.495286
# ...

# %%
cot = cointegration(final_currencies_train['CLP/USD'],final_commodities_train['Copper/usd'])

df_coint = pd.DataFrame(0, index=df_corr.index, columns=df_corr.columns)
half_lifes = pd.DataFrame(0, index=df_corr.index, columns=df_corr.columns)
df_stationarity = pd.DataFrame(0, index=df_corr.index, columns=df_corr.columns)
df_betas = pd.DataFrame(0, index=df_corr.index, columns=df_corr.columns)
df_alphas = pd.DataFrame(0, index=df_corr.index, columns=df_corr.columns)

for i in range(0,len(corr_rows)):
    for j in range(0,len(corr_cols)):
        df_coint.iloc[i,j] = cointegration(final_currencies_train.iloc[:,i],final_commodities_train.iloc[:,j])[0]
        half_lifes.iloc[i,j] = cointegration(final_currencies_train.iloc[:,i],final_commodities_train.iloc[:,j])[1]
        df_stationarity.iloc[i,j] = cointegration(final_currencies_train.iloc[:,i],final_commodities_train.iloc[:,j])[3]
        df_betas.iloc[i,j] = cointegration(final_currencies_train.iloc[:,i],final_commodities_train.iloc[:,j])[4]
        df_alphas.iloc[i,j] = cointegration(final_currencies_train.iloc[:,i],final_commodities_train.iloc[:,j])[5]
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
visualize_data(df_coint,[1,-4])
visualize_data(exports_latam,[0,0.5])
# Out:
#          Copper/usd  Alum/usd  meat/usd  soybean/usd  crudeoil/usd  \
# BRL/USD   -2.702411 -2.188878 -2.080154    -2.169029     -2.747580
# CLP/USD   -3.489553 -2.459169 -3.091318    -2.889883     -3.403494
# ARS/USD   -1.569334 -1.538867 -3.358502    -1.586646     -1.501703
# MXN/USD   -1.279780 -0.700443 -2.263743    -0.949188     -0.888736
# COP/USD   -2.416103 -1.497006 -2.079585    -1.739291     -2.321824
#
#          ironore/usd  corn/usd  sugar/usd  coffee/usd  wheat/usd  gold/usd  \
# BRL/USD    -1.076708 -1.629296  -1.540394   -2.974633  -1.825862 -1.809030
# CLP/USD    -1.456223 -2.344501  -2.534701   -3.274407  -2.473210 -2.254937
# ARS/USD     0.319988 -1.799567  -3.415195   -2.668267  -2.616122 -2.051839
# MXN/USD     0.477253 -1.224405  -1.562332   -1.683211  -2.669353 -0.667079
# COP/USD    -0.231346 -1.447100  -1.468139   -2.436709  -2.056433 -1.320859
#
#          silver/usd
# BRL/USD   -1.943037
# CLP/USD   -2.004112
# ARS/USD   -1.155014
# MXN/USD   -0.748946
# ...

# %% [markdown]
# Ranking system to choose pairs to perform strategy

# %%
final_corr = df_corr.T.values.ravel('F')
final_coint = df_coint.T.values.ravel('F')
final_station = df_stationarity.T.values.ravel('F')
final_gdp = exports_latam.T.values.ravel('F')
final_hl = half_lifes.T.values.ravel('F')
final_betas = df_betas.T.values.ravel('F')
final_alphas = df_alphas.T.values.ravel('F')

tt = []
for i in range(0,len(corr_rows)):
    for j in range(0,len(corr_cols)):
        tt.append(corr_rows[i]+corr_cols[j])
 
halflifes_final = pd.DataFrame(final_hl,index = tt)
betas_final = pd.DataFrame(final_betas,index = tt)
alphas_final = pd.DataFrame(final_alphas,index = tt)
       
final_col = ['Correlation','Cointegration','Stationarity','% Exports']
final_rankings_all = pd.DataFrame(0,index = tt,columns = final_col)
final_rankings_all['Correlation'] = final_corr
final_rankings_all['Cointegration'] = final_coint
final_rankings_all['Stationarity'] = final_station
final_rankings_all['% Exports'] = final_gdp

final_rankings_all.head()
# Out:
#                      Correlation  Cointegration  Stationarity  % Exports
# BRL/USDCopper/usd       0.905552      -2.702411             1      0.010
# BRL/USDAlum/usd         0.745344      -2.188878             0      0.010
# BRL/USDmeat/usd         0.442350      -2.080154             0      0.064
# BRL/USDsoybean/usd      0.810261      -2.169029             0      0.127
# BRL/USDcrudeoil/usd     0.946065      -2.747580             1      0.060

# %% [markdown]
# Chosen Pairs

# %%
chosen_pairs = final_rankings_all[(final_rankings_all['Correlation']>0.59)&(final_rankings_all['Stationarity']==1)&(final_rankings_all['% Exports']>0)]
chosen_pairs_t = chosen_pairs.append(final_rankings_all.loc['COP/USDcrudeoil/usd'])
chosen_pairs_train = chosen_pairs_t.append(final_rankings_all.loc['CLP/USDsoybean/usd'])
chosen_pairs_train = chosen_pairs_train.drop(['ARS/USDwheat/usd'])
chosen_pairs_train.head()
# Out:
#                      Correlation  Cointegration  Stationarity  % Exports
# BRL/USDCopper/usd       0.905552      -2.702411           1.0     0.0100
# BRL/USDcrudeoil/usd     0.946065      -2.747580           1.0     0.0600
# BRL/USDcoffee/usd       0.598385      -2.974633           1.0     0.0270
# CLP/USDCopper/usd       0.928844      -3.489553           1.0     0.4480
# CLP/USDcrudeoil/usd     0.924049      -3.403494           1.0     0.0025

# %%
clp = final_currencies['CLP/USD']
soy_beans = final_commodities['soybean/usd']
brl = final_currencies['BRL/USD']
coffee = final_commodities['coffee/usd']
ars = final_currencies['ARS/USD']
meat = final_commodities['meat/usd']
iron = final_commodities['ironore/usd']
copper = final_commodities['Copper/usd']
cop = final_currencies['COP/USD']
pen = final_currencies['PEN/USD']
mex = final_currencies['MXN/USD']

# %%
def linear_func(B, x):
    return B[0]*x+B[1]
def TLS(x,y):
    linear=Model(linear_func)
    linreg = stats.linregress(x,y)
    dat = Data(x,y)
    od = ODR(dat, linear, beta0=linreg[0:2])
    out = od.run()
    return out.beta[0]

# %% [markdown]
# Training Set Residuals (70% of data, 2014-2017)

# %% [markdown]
# beta_brlcoffee = TLS(coffee[:725],brl[:725])
# beta_arsmeat = TLS(meat[:725],ars[:725])
# beta_clpsoybean = TLS(soy_beans[:725],clp[:725])
# beta_clpiron = TLS(iron[:725],clp[:725])
# beta_clpmeat = TLS(meat[:725],clp[:725])
# beta_copcoffee = TLS(coffee[:725],cop[:725])
# beta_clpcopper = TLS(copper[:725],clp[:725])
# beta_mexmeat = TLS(meat[:725],mex[:725])
# beta_pencoffee = TLS(coffee[:725],pen[:725])

# %%
## Pairs Chosen: CLP/soy beans, BRL/Coffee,ARS/Meat,CLP/ironore
## clp/meat, cop/cofeem clp/cop, pen/coffee

chosen = chosen_pairs_train.index
chosen_halflifes = halflifes_final.loc[chosen].astype('int64')
chosen_betas = betas_final.loc[chosen]
chosen_alphas = alphas_final.loc[chosen]

residuals_trainx=[]
residuals_train_strategyx = []
residuals_train = pd.DataFrame(columns = tt,index = final_commodities_train.index)
residuals_train_strategy = pd.DataFrame(columns = chosen,index = final_commodities_train.index)

for i in range(0,len(corr_rows)):
    for j in range(0,len(corr_cols)):
        residuals_trainx.append(cointegration(final_currencies_train.iloc[:,i],final_commodities_train.iloc[:,j])[2])
        
#final_currencies_train.iloc[:,i],final_commodities_train.iloc[:,j]
residuals_train = pd.concat(residuals_trainx,axis=1, join='inner')
residuals_train.columns = tt
chosen_residuals_train = residuals_train[chosen]
chosen_residuals_train_f = []

for i in range(0,len(chosen_residuals_train.columns)):
    chosen_residuals_train_f.append(chosen_residuals_train.iloc[:,i] + chosen_alphas.iloc[i,0])

chosen_residuals_train_f = pd.concat(chosen_residuals_train_f,axis=1, join='inner')

residuals_train_strategy.loc[:,chosen[0]] = final_currencies_train.loc[:,'CLP/USD'] - (chosen_betas.iloc[0,0]*final_commodities_train.loc[:,'Copper/usd'])#chosen_alphas.iloc[0,0]
residuals_train_strategy.loc[:,chosen[1]] = final_currencies_train.loc[:,'CLP/USD'] - (chosen_betas.iloc[1,0]*final_commodities_train.loc[:,'crudeoil/usd'])#-chosen_alphas.iloc[1,0]
residuals_train_strategy.loc[:,chosen[2]] = final_currencies_train.loc[:,'ARS/USD'] - (chosen_betas.iloc[2,0]*final_commodities_train.loc[:,'meat/usd'])#-chosen_alphas.iloc[2,0]
residuals_train_strategy.loc[:,chosen[3]] = final_currencies_train.loc[:,'BRL/USD'] - (chosen_betas.iloc[3,0]*final_commodities_train.loc[:,'coffee/usd'])#-chosen_alphas.iloc[3,0]
residuals_train_strategy.loc[:,chosen[4]] = final_currencies_train.loc[:,'BRL/USD'] - (chosen_betas.iloc[4,0]*final_commodities_train.loc[:,'crudeoil/usd'])#-chosen_alphas.iloc[4,0]
residuals_train_strategy.loc[:,chosen[5]] = final_currencies_train.loc[:,'BRL/USD'] - (chosen_betas.iloc[5,0]*final_commodities_train.loc[:,'Copper/usd'])#-chosen_alphas.iloc[5,0]
residuals_train_strategy.loc[:,chosen[6]] = final_currencies_train.loc[:,'MXN/USD'] - (chosen_betas.iloc[6,0]*final_commodities_train.loc[:,'wheat/usd'])#-chosen_alphas.iloc[6,0]
residuals_train_strategy.loc[:,chosen[7]] = final_currencies_train.loc[:,'COP/USD'] - (chosen_betas.iloc[7,0]*final_commodities_train.loc[:,'crudeoil/usd'])#-chosen_alphas.iloc[7,0]
residuals_train_strategy.loc[:,chosen[8]] = final_currencies_train.loc[:,'CLP/USD'] - (chosen_betas.iloc[8,0]*final_commodities_train.loc[:,'soybean/usd'])#-chosen_alphas.iloc[8,0]

# %% [markdown]
# Residual CLP vs Copper Plot with +,- 1 std and +,- 2 std

# %%
ratio = chosen_residuals_train['CLP/USDCopper/usd']
ratio.plot()
plt.axhline(ratio.mean(),color = 'black')
plt.axhline(ratio.mean()+np.std(ratio), color='red',linestyle='--')
plt.axhline(ratio.mean()-np.std(ratio), color='red',linestyle='--')
plt.axhline(ratio.mean()+2*np.std(ratio), color='green',linestyle='--')
plt.axhline(ratio.mean()-2*np.std(ratio), color='green',linestyle='--')
plt.legend(['Residuals','Mean','std'])
plt.title('Residuals CLP vs Copper')
# Out:
# Text(0.5, 1.0, 'Residuals CLP vs Copper')

# %% [markdown]
# Implement Pair Trading Strategy function with outputs of returns, sharpe ratio, maximum drawdowns, number of trades and hit ratios

# %%
def var_cov_var(P, c, mu, sigma):

    alpha = norm.ppf(1-c, mu, sigma)
    return P - P*(alpha + 1)


def backtest(residuals,window):
    df1 = pd.DataFrame({'y':residuals}) 
    df1['spread'] = residuals
    
    # select window
    halflife = window
    
    #mean and std
    meanSpread = df1.spread.rolling(window=halflife).mean()
    stdSpread = df1.spread.rolling(window=halflife).std()
    
    ##############################################################
    # trading logic
    entryLong = meanSpread - stdSpread
    entryShort = meanSpread + stdSpread
    
    #set up num units long
    df1['long entry'] = (df1.spread > entryLong) &  (df1.spread < meanSpread)
    df1['long exit'] = (df1.spread >= meanSpread) 
    df1['num units long'] = np.nan 
    df1.loc[df1['long entry'],'num units long'] = 1 
    df1.loc[df1['long exit'],'num units long'] = 0 
    df1['num units long'][0] = 0 
    df1['num units long'] = df1['num units long'].fillna(method='pad') 
    #set up num units short 
    df1['short entry'] = (df1.spread < entryShort) &  (df1.spread > meanSpread)
    df1['short exit'] = (df1.spread <= meanSpread) 
    df1.loc[df1['short entry'],'num units short'] = -1
    df1.loc[df1['short exit'],'num units short'] = 0
    df1['num units short'][0] = 0
    df1['num units short'] = df1['num units short'].fillna(method='pad')
    
    df1['numUnits'] = df1['num units long'] + df1['num units short']
    df1['spread pct ch'] = (df1['spread']-df1['spread'].shift(1)) / df1['spread']
    df1['port rets'] = df1['spread pct ch'] * df1['numUnits'].shift(1)
    
    df1['cum rets'] = df1['port rets'].cumsum()
    df1['cum rets'] = df1['cum rets'] + 1
    
    try:
        sharpe = (df1['port rets'].mean() / df1['port rets'].std()) *np.sqrt(252)
    except ZeroDivisionError:
        sharpe = 0.0
      
    maximums = np.maximum.accumulate(df1['cum rets'].dropna().values)
    drawdowns = 1 - (df1['cum rets'].dropna().values) / maximums
    max_drawdowns = np.amax(drawdowns)*100
    
    counters = 0
    for i in range(1, len(df1['numUnits'])):
        if (df1['numUnits'].iloc[i-1] != 0)& (df1['numUnits'].iloc[i] != df1['numUnits'].iloc[i-1]):
            counters += 1
    
    df1['hitratio'] = ""
    for i in range(1, len(df1['port rets'])):
        if df1['port rets'].iloc[i] > df1['port rets'].iloc[i-1]:
            df1['hitratio'].iloc[i] = 'yes'
        if df1['port rets'].iloc[i] < df1['port rets'].iloc[i-1]:
            df1['hitratio'].iloc[i] = 'no'
    
    hit_ratio = (df1.hitratio.str.count("yes").sum()/(df1.hitratio.str.count("no").sum()+df1.hitratio.str.count("yes").sum()))*100
    
    P = 1e6   # 1,000,000 USD
    c = 0.99  # 99% confidence interval
    mu = np.mean(df1['port rets'])
    sigma = np.std(df1['port rets'])

    var = var_cov_var(P, c, mu, sigma)
    
    return df1['cum rets'], sharpe , max_drawdowns, counters, var

# %% [markdown]
# Training output tables and values

# %%
tt_res_col = ['Total Returns','Sharpe Ratio','Maximum Drawdown','Number of Trades','VaR']#,'Hit Ratio']
train_df = pd.DataFrame(columns=tt_res_col,index = chosen)

backtes = backtest(chosen_residuals_train.iloc[:,0],24)

q_train = []
q_test = []
#plt.plot(clpcoppper_ret-1)
for i in range(0,len(chosen_pairs_train)):
    q_train.append(backtest(chosen_residuals_train_f.iloc[:,i],chosen_halflifes.iloc[i,0]))

for i in range(0,len(chosen_pairs_train)):
    train_df.iloc[i,0] = q_train[i][0][-1]
    train_df.iloc[i,1] = q_train[i][1]
    train_df.iloc[i,2] = q_train[i][2]
    train_df.iloc[i,3] = q_train[i][3]
    train_df.iloc[i,4] = q_train[i][4]

train_df.iloc[:,0] = (train_df.iloc[:,0] - 1)*100
train_df['VaR'] = train_df['VaR']*-1
train_df['VaR'].loc['BRL/USDCopper/usd'] = train_df['VaR'].loc['BRL/USDCopper/usd']  *-1
train_df['VaR'].loc['MXN/USDwheat/usd'] = train_df['VaR'].loc['MXN/USDwheat/usd']  *-1



ret_train = pd.concat([q_train[0][0],q_train[1][0],q_train[2][0],q_train[3][0],
q_train[4][0],q_train[5][0],q_train[6][0],q_train[7][0],q_train[8][0]],axis = 1).dropna()
ret_train = (ret_train - 1)*100

ret_train.columns = train_df.index
train_df
# Out:
#                     Total Returns Sharpe Ratio Maximum Drawdown  \
# BRL/USDCopper/usd         3242.76     0.177839          544.204
# BRL/USDcrudeoil/usd       69.9551     0.675239          37.3612
# BRL/USDcoffee/usd        -87.6184    -0.370739          92.0146
# CLP/USDCopper/usd         88.4135      1.22682          17.2656
# CLP/USDcrudeoil/usd       22.2948     0.615315          10.9468
# ARS/USDmeat/usd           59.4214     0.236565          56.3877
# MXN/USDwheat/usd         -253.155    -0.434664          452.991
# COP/USDcrudeoil/usd       45.9375     0.499449          42.4986
# CLP/USDsoybean/usd       -8.37245    -0.117172          47.3519
#
#                     Number of Trades          VaR
# BRL/USDCopper/usd                 63  9.24965e+06
# BRL/USDcrudeoil/usd               79     -51841.6
# BRL/USDcoffee/usd                 37      -121676
# CLP/USDCopper/usd                108     -35513.3
# CLP/USDcrudeoil/usd               71       -18161
# ...

# %% [markdown]
# Cumulative Return Plot of the 9 pairs

# %%
t_brpo = ret_train[ret_train.columns.difference(['BRL/USDCopper/usd'])]
t_brpo = ret_train[t_brpo.columns.difference(['MXN/USDwheat/usd'])]


ret_train['BRL/USDCopper/usd'].plot(secondary_y=True)

plt.figure(figsize=(13,7))
plt.plot(t_brpo)
plt.ylim(-100)
plt.ylabel('% Returns')
plt.xlabel('Date')
plt.title("Returns on Train Set")
plt.legend(t_brpo.columns.values,prop={'size': 10})

# %% [markdown]
# Now apply the strategy for the test set of the 30% remaining data. In this case we only use the three best performing pairs and see how they would perform in the real world. I used the same betas from the previous training strategy, with the same moving window of 65 days. I invested a hypothetical 1 million dollar investment between these three pairs where I invested 80% into CLP/copper and the remaining 20% between CLP/Meat and CLP/Iron ore. The code shows the data processing, residuals and final performance of the portfolio.

# %%
final_commodities_test = df_total.iloc[725:,0:12]
final_currencies_test = df_total.iloc[725:,12:18]

test_col = ['CLP/USDCopper/usd','CLP/USDcrudeoil/usd','BRL/USDcrudeoil/usd']
chosen_pairs_test = chosen_pairs_train.loc[test_col]
chosen_residuals_test = pd.DataFrame(columns = test_col,index = final_commodities_test.index)
chosen_residuals_test['CLP/USDCopper/usd'] = final_currencies_test['CLP/USD']-chosen_betas.loc['CLP/USDCopper/usd',0]*final_commodities_test['Copper/usd']
chosen_residuals_test['CLP/USDcrudeoil/usd'] = final_currencies_test['CLP/USD']-chosen_betas.loc['CLP/USDcrudeoil/usd',0]*final_commodities_test['crudeoil/usd']
chosen_residuals_test['BRL/USDcrudeoil/usd'] = final_currencies_test['BRL/USD']-chosen_betas.loc['BRL/USDcrudeoil/usd',0]*final_commodities_test['crudeoil/usd']
#chosen_residuals_test['COP/USDcrudeoil/usd'] = final_currencies_test['COP/USD']-chosen_betas.loc['BRL/USDcrudeoil/usd',0]*final_commodities_test['crudeoil/usd']

chosen_halflifes_test = chosen_halflifes.loc[test_col]

test_df = pd.DataFrame(columns=tt_res_col,index = test_col)

q_test = []
for i in range(0,len(test_col)):
    q_test.append(backtest(chosen_residuals_test.iloc[:,i],chosen_halflifes_test.iloc[i,0]))

for i in range(0,len(test_col)):
    test_df.iloc[i,0] = q_test[i][0][-1]
    test_df.iloc[i,1] = q_test[i][1]
    test_df.iloc[i,2] = q_test[i][2]
    test_df.iloc[i,3] = q_test[i][3]
    test_df.iloc[i,4] = q_test[i][4]

test_df.iloc[:,0] = (test_df.iloc[:,0] - 1)*100
test_df
# Out:
#                     Total Returns Sharpe Ratio Maximum Drawdown  \
# CLP/USDCopper/usd         29.7061     0.718992          25.5053
# CLP/USDcrudeoil/usd      -6.14732    -0.310258          18.3954
# BRL/USDcrudeoil/usd      -25.0157    -0.304767          63.4299
#
#                     Number of Trades      VaR
# CLP/USDCopper/usd                 39    42928
# CLP/USDcrudeoil/usd               30  21172.5
# BRL/USDcrudeoil/usd               24  87697.9

# %%
total_returns_test =[]
for i in range(0,len(test_col)):
    total_returns_train.append(q_train[i][0])

portfolio_returns_train = pd.concat(total_returns_train,axis=1, join='inner')
portfolio_returns_train['Total']= portfolio_returns_train.sum(axis=1)/9

ret_test = pd.concat([q_test[0][0],q_test[1][0],q_test[2][0]],axis = 1).dropna()
ret_test = (ret_test - 1)*100
ret_test.columns = test_col

plt.figure(figsize=(13,7))
plt.plot(ret_test)
plt.ylim(-60)
plt.ylabel('% Returns')
plt.xlabel('Date')
plt.title("Returns on Test Set")
plt.legend(ret_test.columns.values,prop={'size': 10})

# %% [markdown]
# **BONUS: residual graph with train and test set together of CLP/copper for the whole data set

# %%
plt.figure(figsize=(10,5))
plt.plot(chosen_residuals_train_f['CLP/USDCopper/usd'])
plt.plot(chosen_residuals_test['CLP/USDCopper/usd'])
plt.legend(['Residuals Train','Residuals Test'])
plt.title('Residuals CLP vs Copper')
# Out:
# Text(0.5, 1.0, 'Residuals CLP vs Copper')
